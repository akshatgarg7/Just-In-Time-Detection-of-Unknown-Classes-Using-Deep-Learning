# %% [markdown]
# ### Importing required libaries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import random
from PIL import Image
import PIL.ImageOps    
import os

import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset
import torchvision.utils
import torch
from torch.autograd import Variable
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

from models.old_model import SiameseNetwork

from losses.euclidean import ContrastiveLoss
from losses.cosine import ContrastiveLossCosine

from utils.vis_utils import imshow, show_plot
from utils.other_utils import joinpath, SiameseNetworkDataset, SiameseNetworkDataset_for_test, get_dataset
from utils.other_utils import intersection, threshold

# %%
# Setup the path where images are located
PATH = r"H:\Just-In-Time-Detection-of-Unknown-Classes-Using-Deep-Learning\data\faces"


# Setup the number of channels in the image, 3 for color, 1 for monochrome
nchannel=1

# no of epoch
EPOCH = 200

# if testing
testing = False

# Threshold score
THRESHOLD_SCORE = 0.3

# %%
# Resize the images and transform to tensors
transformation = transforms.Compose([transforms.Resize((100,100)),
                                     transforms.ToTensor()])

transformation_for_test = transforms.Compose([transforms.Resize((100,100)),
    transforms.ToTensor(), 
    transforms.RandomApply([
         transforms.RandomRotation([-180,180])], p = 0.2)
])

# %%
os.cpu_count() #cpu count
# Out:
# 16

# %% [markdown]
# For simple visualization purposes let’s look at this example.
# Create a DataLoader of the siamese_dataset and extract the first batch only.
# Combine each combination of images, because our siamese_datasetwill return two images and one label, and print out the labels.

# %%
# Create a simple dataloader just for simple visualization
vis_dataloader,_ = get_dataset(joinpath(PATH,'train'),transformation,SiameseNetworkDataset,0,8,True)

# Extract one batch
example_batch = next(iter(vis_dataloader))

# Example batch is a list containing 2x8 images, indexes 0 and 1, an also the label
# If the label is 1, it means that it is not the same person, label is 0, same person in both images
concatenated = torch.cat((example_batch[0], example_batch[1]),0)

imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy().reshape(-1))
# Out:
# [0. 1. 0. 1. 1. 1. 1. 0.]

# %%
# Load the training dataset
train_dataloader,_ = get_dataset(joinpath(PATH,'train'), transformation_for_test, SiameseNetworkDataset, 0, 64, True)
net = SiameseNetwork(nchannel).cuda()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(), lr = 0.0005 )

# %%
print(net)
# Out:
# SiameseNetwork(
#   (cnn1): Sequential(
#     (0): Conv2d(1, 96, kernel_size=(11, 11), stride=(4, 4))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(96, 256, kernel_size=(5, 5), stride=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1))
#     (7): ReLU(inplace=True)
#   )
#   (fc1): Sequential(
#     (0): Linear(in_features=384, out_features=1024, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=1024, out_features=256, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#   )
# )

# %%
from torchsummary import summary
summary(net, [(nchannel, 100, 100), (nchannel, 100, 100)])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 96, 23, 23]          11,712
#               ReLU-2           [-1, 96, 23, 23]               0
#          MaxPool2d-3           [-1, 96, 11, 11]               0
#             Conv2d-4            [-1, 256, 7, 7]         614,656
#               ReLU-5            [-1, 256, 7, 7]               0
#          MaxPool2d-6            [-1, 256, 3, 3]               0
#             Conv2d-7            [-1, 384, 1, 1]         885,120
#               ReLU-8            [-1, 384, 1, 1]               0
#             Linear-9                 [-1, 1024]         394,240
#              ReLU-10                 [-1, 1024]               0
#            Linear-11                  [-1, 256]         262,400
#              ReLU-12                  [-1, 256]               0
#            Linear-13                  [-1, 128]          32,896
#            Conv2d-14           [-1, 96, 23, 23]          11,712
#              ReLU-15           [-1, 96, 23, 23]               0
#         MaxPool2d-16           [-1, 96, 11, 11]               0
#            Conv2d-17            [-1, 256, 7, 7]         614,656
#              ReLU-18            [-1, 256, 7, 7]               0
#         MaxPool2d-19            [-1, 256, 3, 3]               0
#            Conv2d-20            [-1, 384, 1, 1]         885,120
#              ReLU-21            [-1, 384, 1, 1]               0
#            Linear-22                 [-1, 1024]         394,240
#              ReLU-23                 [-1, 1024]               0
#            Linear-24                  [-1, 256]         262,400
#              ReLU-25                  [-1, 256]               0
#            Linear-26                  [-1, 128]          32,896
# ================================================================
# Total params: 4,402,048
# Trainable params: 4,402,048
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 381.47
# Forward/backward pass size (MB): 2.20
# Params size (MB): 16.79
# Estimated Total Size (MB): 400.46
# ----------------------------------------------------------------

# %% [markdown]
# Following the flow diagram from the top, we can start creating the training loop. We iterate 200 times and extract the two images as well as the label. We zero the gradients and pass our two images into the network, and the network outputs two vectors. The two vectors, and the label, are then fed into the criterion (loss function) that we defined. We backpropagate and optimize. For some visualization purposes and to see how our model is performing on the training set, so we will print the loss every 10 batches.

# %%
def train(epochs = EPOCH):

    counter = []
    loss_history = [] 
    iteration_number= 0

    # Iterate throught the epochs
    for epoch in range(epochs):

    # Iterate over batches
        for i, (img0, img1, label) in enumerate(train_dataloader, 0):

            # Send the images and labels to CUDA
            img0, img1, label = img0.cuda(), img1.cuda(), label.cuda()

            # Zero the gradients
            optimizer.zero_grad()

            # Pass in the two images into the network and obtain two outputs
            output1, output2 = net(img0, img1)

            # Pass the outputs of the networks and label into the loss function
            loss_contrastive = criterion(output1, output2, label)

            # Calculate the backpropagation
            loss_contrastive.backward()

            # Optimize
            optimizer.step()

            # Every 10 batches print out the loss
            if i % 10 == 0 :
                print(f"Epoch number {epoch}\n Current loss {loss_contrastive.item()}\n")
                iteration_number += 10

                counter.append(iteration_number)
                loss_history.append(loss_contrastive.item())
    return (counter,loss_history)

# %%
counter,loss_history = train(EPOCH)

# Plotting the loss vs epoch
plt.figure()
plt.title('Loss vs Epoch for euclidean distance')
plt.xlabel("epoch", fontsize=12)
plt.ylabel("loss", fontsize=12)
show_plot(counter, loss_history)
# Out:
# Epoch number 0
#  Current loss 1.607834815979004
#
# Epoch number 1
#  Current loss 0.8719480037689209
#
# Epoch number 2
#  Current loss 1.2137212753295898
#
# Epoch number 3
#  Current loss 0.6350939273834229
#
# Epoch number 4
#  Current loss 0.9994860887527466
#
# Epoch number 5
#  Current loss 0.8384681940078735
#
# Epoch number 6
#  Current loss 0.47092464566230774
#
# Epoch number 7
#  Current loss 0.5423305034637451
#
# Epoch number 8
#  Current loss 0.608353316783905
#
# Epoch number 9
#  Current loss 0.610697865486145
#
# Epoch number 10
#  Current loss 0.51408451795578
#
# Epoch number 11
#  Current loss 0.5866646766662598
#
# Epoch number 12
#  Current loss 0.636342465877533
#
# Epoch number 13
#  Current loss 0.4867876470088959
#
# Epoch number 14
#  Current loss 0.370961457490921
#
# Epoch number 15
#  Current loss 0.5523027181625366
#
# Epoch number 16
#  Current loss 0.5177739858627319
#
# Epoch number 17
#  Current loss 0.5503751635551453
#
# Epoch number 18
#  Current loss 0.3500382900238037
#
# Epoch number 19
#  Current loss 0.3520265817642212
#
# Epoch number 20
#  Current loss 0.45674604177474976
#
# Epoch number 21
#  Current loss 0.6361716389656067
#
# Epoch number 22
#  Current loss 0.287703275680542
#
# Epoch number 23
#  Current loss 0.4381779432296753
#
# Epoch number 24
#  Current loss 0.44716766476631165
#
# Epoch number 25
#  Current loss 0.35276293754577637
#
# Epoch number 26
#  Current loss 0.3334655165672302
#
# Epoch number 27
#  Current loss 0.43128645420074463
#
# Epoch number 28
#  Current loss 0.5714354515075684
#
# Epoch number 29
#  Current loss 0.4824255704879761
#
# Epoch number 30
#  Current loss 0.5105944871902466
#
# Epoch number 31
#  Current loss 0.28101232647895813
#
# Epoch number 32
#  Current loss 0.3915877044200897
#
# Epoch number 33
#  Current loss 0.35591086745262146
#
# Epoch number 34
#  Current loss 0.25130075216293335
#
# Epoch number 35
#  Current loss 0.273716539144516
#
# Epoch number 36
#  Current loss 0.3818674385547638
#
# Epoch number 37
#  Current loss 0.39249855279922485
#
# Epoch number 38
#  Current loss 0.4184221029281616
#
# Epoch number 39
#  Current loss 0.30335918068885803
#
# Epoch number 40
#  Current loss 0.3067654073238373
#
# Epoch number 41
#  Current loss 0.27524271607398987
#
# Epoch number 42
#  Current loss 0.32789790630340576
#
# Epoch number 43
#  Current loss 0.2820148766040802
#
# Epoch number 44
#  Current loss 0.446124792098999
#
# Epoch number 45
#  Current loss 0.2487146109342575
#
# Epoch number 46
#  Current loss 0.2946699261665344
#
# Epoch number 47
#  Current loss 0.3219278156757355
#
# Epoch number 48
#  Current loss 0.3977290689945221
#
# Epoch number 49
#  Current loss 0.26745736598968506
#
# Epoch number 50
#  Current loss 0.35396867990493774
#
# Epoch number 51
#  Current loss 0.4809231460094452
#
# Epoch number 52
#  Current loss 0.23258280754089355
#
# Epoch number 53
#  Current loss 0.27795350551605225
#
# Epoch number 54
#  Current loss 0.3024511933326721
#
# Epoch number 55
#  Current loss 0.35095512866973877
#
# Epoch number 56
#  Current loss 0.267341285943985
#
# Epoch number 57
#  Current loss 0.2919332683086395
#
# Epoch number 58
#  Current loss 0.22892744839191437
#
# Epoch number 59
#  Current loss 0.24975109100341797
#
# Epoch number 60
#  Current loss 0.2787259817123413
#
# Epoch number 61
#  Current loss 0.2842462956905365
#
# Epoch number 62
#  Current loss 0.17671966552734375
#
# Epoch number 63
#  Current loss 0.31895148754119873
#
# Epoch number 64
#  Current loss 0.342894047498703
#
# Epoch number 65
#  Current loss 0.33383384346961975
#
# Epoch number 66
#  Current loss 0.25948721170425415
#
# Epoch number 67
#  Current loss 0.18741555511951447
#
# Epoch number 68
#  Current loss 0.22492709755897522
#
# Epoch number 69
#  Current loss 0.28085169196128845
#
# Epoch number 70
#  Current loss 0.2552366852760315
#
# Epoch number 71
#  Current loss 0.3410123288631439
#
# Epoch number 72
#  Current loss 0.2511911392211914
#
# Epoch number 73
#  Current loss 0.23340296745300293
#
# Epoch number 74
#  Current loss 0.2486121952533722
#
# Epoch number 75
#  Current loss 0.25134557485580444
#
# Epoch number 76
#  Current loss 0.18272706866264343
#
# Epoch number 77
#  Current loss 0.2127285897731781
#
# Epoch number 78
#  Current loss 0.316779762506485
#
# Epoch number 79
#  Current loss 0.2885490357875824
#
# Epoch number 80
#  Current loss 0.2989947199821472
#
# Epoch number 81
#  Current loss 0.2069777548313141
#
# Epoch number 82
#  Current loss 0.2915402948856354
#
# Epoch number 83
#  Current loss 0.2878791391849518
#
# Epoch number 84
#  Current loss 0.15101535618305206
#
# Epoch number 85
#  Current loss 0.21448718011379242
#
# Epoch number 86
#  Current loss 0.1731540560722351
#
# Epoch number 87
#  Current loss 0.22614942491054535
#
# Epoch number 88
#  Current loss 0.3094636797904968
#
# Epoch number 89
#  Current loss 0.25959649682044983
#
# Epoch number 90
#  Current loss 0.19368420541286469
#
# Epoch number 91
#  Current loss 0.18681001663208008
#
# Epoch number 92
#  Current loss 0.242615208029747
#
# Epoch number 93
#  Current loss 0.22536888718605042
#
# Epoch number 94
#  Current loss 0.16873249411582947
#
# Epoch number 95
#  Current loss 0.1847711205482483
#
# Epoch number 96
#  Current loss 0.23236343264579773
#
# Epoch number 97
#  Current loss 0.11877664923667908
#
# Epoch number 98
#  Current loss 0.2704891264438629
#
# Epoch number 99
#  Current loss 0.38187164068222046
#
# Epoch number 100
#  Current loss 0.33440282940864563
#
# Epoch number 101
#  Current loss 0.23187637329101562
#
# Epoch number 102
#  Current loss 0.23949110507965088
#
# Epoch number 103
#  Current loss 0.12759104371070862
#
# Epoch number 104
#  Current loss 0.2791653871536255
#
# Epoch number 105
#  Current loss 0.21854466199874878
#
# Epoch number 106
#  Current loss 0.24293002486228943
#
# Epoch number 107
#  Current loss 0.19417312741279602
#
# Epoch number 108
#  Current loss 0.28037571907043457
#
# Epoch number 109
#  Current loss 0.26541659235954285
#
# Epoch number 110
#  Current loss 0.21914833784103394
#
# Epoch number 111
#  Current loss 0.27779898047447205
#
# Epoch number 112
#  Current loss 0.21922501921653748
#
# Epoch number 113
#  Current loss 0.18578675389289856
#
# Epoch number 114
#  Current loss 0.1912764608860016
#
# Epoch number 115
#  Current loss 0.18399283289909363
#
# Epoch number 116
#  Current loss 0.11549320071935654
#
# Epoch number 117
#  Current loss 0.1994580775499344
#
# Epoch number 118
#  Current loss 0.20159177482128143
#
# Epoch number 119
#  Current loss 0.24173563718795776
#
# Epoch number 120
#  Current loss 0.12574897706508636
#
# Epoch number 121
#  Current loss 0.24268639087677002
#
# Epoch number 122
#  Current loss 0.18158972263336182
#
# Epoch number 123
#  Current loss 0.17545060813426971
#
# Epoch number 124
#  Current loss 0.16072455048561096
#
# Epoch number 125
#  Current loss 0.14816364645957947
#
# Epoch number 126
#  Current loss 0.1501987874507904
#
# Epoch number 127
#  Current loss 0.17713245749473572
#
# Epoch number 128
#  Current loss 0.0924670398235321
#
# Epoch number 129
#  Current loss 0.21768702566623688
#
# Epoch number 130
#  Current loss 0.23733748495578766
#
# Epoch number 131
#  Current loss 0.20534849166870117
#
# Epoch number 132
#  Current loss 0.15032535791397095
#
# Epoch number 133
#  Current loss 0.29681313037872314
#
# Epoch number 134
#  Current loss 0.16253650188446045
#
# Epoch number 135
#  Current loss 0.18686868250370026
#
# Epoch number 136
#  Current loss 0.2645738124847412
#
# Epoch number 137
#  Current loss 0.11866100132465363
#
# Epoch number 138
#  Current loss 0.16560541093349457
#
# Epoch number 139
#  Current loss 0.21375438570976257
#
# Epoch number 140
#  Current loss 0.1351676881313324
#
# Epoch number 141
#  Current loss 0.12881650030612946
#
# Epoch number 142
#  Current loss 0.17573468387126923
#
# Epoch number 143
#  Current loss 0.17959941923618317
#
# Epoch number 144
#  Current loss 0.20325332880020142
#
# Epoch number 145
#  Current loss 0.1507958471775055
#
# Epoch number 146
#  Current loss 0.2368605136871338
#
# Epoch number 147
#  Current loss 0.11620483547449112
#
# Epoch number 148
#  Current loss 0.25072601437568665
#
# Epoch number 149
#  Current loss 0.16973809897899628
#
# Epoch number 150
#  Current loss 0.18437856435775757
#
# Epoch number 151
#  Current loss 0.1549704223871231
#
# Epoch number 152
#  Current loss 0.1877727061510086
#
# Epoch number 153
#  Current loss 0.11923088133335114
#
# Epoch number 154
#  Current loss 0.1826135516166687
#
# Epoch number 155
#  Current loss 0.12396685779094696
#
# Epoch number 156
#  Current loss 0.22560054063796997
#
# Epoch number 157
#  Current loss 0.2326512187719345
#
# Epoch number 158
#  Current loss 0.14945803582668304
#
# Epoch number 159
#  Current loss 0.14720454812049866
#
# Epoch number 160
#  Current loss 0.19248849153518677
#
# Epoch number 161
#  Current loss 0.27456533908843994
#
# Epoch number 162
#  Current loss 0.16572877764701843
#
# Epoch number 163
#  Current loss 0.16179858148097992
#
# Epoch number 164
#  Current loss 0.13958331942558289
#
# Epoch number 165
#  Current loss 0.1319161057472229
#
# Epoch number 166
#  Current loss 0.11650623381137848
#
# Epoch number 167
#  Current loss 0.15158790349960327
#
# Epoch number 168
#  Current loss 0.2599562704563141
#
# Epoch number 169
#  Current loss 0.20229747891426086
#
# Epoch number 170
#  Current loss 0.19110867381095886
#
# Epoch number 171
#  Current loss 0.18018077313899994
#
# Epoch number 172
#  Current loss 0.17209838330745697
#
# Epoch number 173
#  Current loss 0.10443568974733353
#
# Epoch number 174
#  Current loss 0.19976727664470673
#
# Epoch number 175
#  Current loss 0.10696378350257874
#
# Epoch number 176
#  Current loss 0.2217002511024475
#
# Epoch number 177
#  Current loss 0.1671445220708847
#
# Epoch number 178
#  Current loss 0.16362696886062622
#
# Epoch number 179
#  Current loss 0.22780193388462067
#
# Epoch number 180
#  Current loss 0.1382514238357544
#
# Epoch number 181
#  Current loss 0.17097295820713043
#
# Epoch number 182
#  Current loss 0.1406497061252594
#
# Epoch number 183
#  Current loss 0.16539070010185242
#
# Epoch number 184
#  Current loss 0.12062937021255493
#
# Epoch number 185
#  Current loss 0.19630908966064453
#
# Epoch number 186
#  Current loss 0.20771192014217377
#
# Epoch number 187
#  Current loss 0.16400843858718872
#
# Epoch number 188
#  Current loss 0.1357387900352478
#
# Epoch number 189
#  Current loss 0.22927019000053406
#
# Epoch number 190
#  Current loss 0.12289168685674667
#
# Epoch number 191
#  Current loss 0.24029280245304108
#
# Epoch number 192
#  Current loss 0.08241739869117737
#
# Epoch number 193
#  Current loss 0.20196987688541412
#
# Epoch number 194
#  Current loss 0.12094125896692276
#
# Epoch number 195
#  Current loss 0.18399980664253235
#
# Epoch number 196
#  Current loss 0.16250190138816833
#
# Epoch number 197
#  Current loss 0.15848714113235474
#
# Epoch number 198
#  Current loss 0.19943031668663025
#
# Epoch number 199
#  Current loss 0.11571025103330612

# %% [markdown]
# We can now analyze the results. The first thing we can see is that the loss started around 1.6 and ended at a number pretty close to 0.
#
# It would be interesting to see the model in action. Now comes the part where we test our model on images it didn’t see before. As we have done before, we create a Siamese Network Dataset using our custom dataset class, but now we point it to the test folder.
#
# As the next steps, we extract the first image from the first batch of the test set and iterate over all the train images to check how it performs.
#
# We pass in the two images into the model and obtain two vectors, which are then passed into theF.pairwise_distance() function, this will calculate the euclidean distance between the two vectors. Using this distance, we can as a metric of how dissimilar the two faces are.

# %%
#### here we create dataiter for test

# Locate the test dataset and load it into the SiameseNetworkDataset_for_test
if testing:
    test_dataloader,_ = get_dataset(joinpath(PATH,'test'), transformation, SiameseNetworkDataset_for_test, 0, 1, True)

    # Grab one image that we are going to test
    dataiter = iter(test_dataloader)
    x0,_ = next(dataiter)


    #### here we create dataiter for train.

    # Locate the test dataset and load it into the SiameseNetworkDataset_for_test
    train_dataloader,siamese_dataset_train = get_dataset(joinpath(PATH,'train'), transformation, SiameseNetworkDataset_for_test, 0, 1, False)

    dataiter_train = iter(train_dataloader)

    score = []

    for i in range(len(siamese_dataset_train)):
        # Iterate over all images and test them with the first image (x0)
        x1,_ = next(dataiter_train)

        # Concatenate the two images together
        concatenated = torch.cat((x0, x1), 0)
        
        output1, output2 = net(x0.cuda(), x1.cuda())
        euclidean_distance = F.pairwise_distance(output1, output2)
        score.append(round(euclidean_distance.item(),2))
        imshow(torchvision.utils.make_grid(concatenated), f'Dissimilarity: {euclidean_distance.item():.2f}')
        # cosine_distance = torch.cosine_similarity(output1, output2)
        # score.append(round(cosine_distance.item(),2))
        # imshow(torchvision.utils.make_grid(concatenated), f'Dissimilarity: {cosine_distance.item():.2f}')

# %% [markdown]
# Now we test all the test images with all the train images and all combination are unique.

# %%
#### here we create dataiter for test

test_dataloader,siamese_dataset = get_dataset(joinpath(PATH,'test'), transformation_for_test, SiameseNetworkDataset_for_test, 0, 1, True)

#### here we create dataiter for train

train_dataloader,siamese_dataset_train = get_dataset(joinpath(PATH,'train'), transformation_for_test, SiameseNetworkDataset_for_test, 0, 1, False)


truth=[]
predict=[]
same_disssimilarity=[]
different_disssimilarity=[]
count_label0 = []
count_label1 = []


dataiter = iter(test_dataloader)
for i in range(len(siamese_dataset)):
    
    x0,label0 = next(dataiter)
    count_label0.append(label0)
    

# Grab one image that we are going to test
    dataiter_train = iter(train_dataloader)

    for i in range(len(siamese_dataset_train)):
    # Iterate over 5 images and test them with the first image (x0)
        x1,label1 = next(dataiter_train)
        count_label1.append(label1)

        # Concatenate the two images together
        concatenated = torch.cat((x0, x1), 0)

        output1, output2 = net(x0.cuda(), x1.cuda())
        euclidean_distance = F.pairwise_distance(output1, output2)
        

        predict.append(euclidean_distance.item())
        if label0==label1: # if labels of two images are same append them to same_dissimilar
            same_disssimilarity.append(euclidean_distance.item())
        else:
            different_disssimilarity.append(euclidean_distance.item())

        # cosine_distance = torch.cosine_similarity(output1, output2)
        # predict.append(cosine_distance.item())
        # if label0==label1:
        #     same_disssimilarity.append(cosine_distance.item())
        # else:
        #     different_disssimilarity.append(cosine_distance.item())

# %%
# checking if there are any intersection in same and different images
print("Number of total interesection: ", len(intersection(same_disssimilarity,different_disssimilarity)))
# Out:
# Number of total interesection:  2502

# %%
# Plotting the distribution for same vs dissimilar images density plot

# %matplotlib widget
import seaborn as sns
import matplotlib.pyplot as plt

# Set custom color palette
colors = ["#E74C3C", "#3498DB"]

# Create figure and axes objects
fig, ax = plt.subplots(figsize=(8, 6))

# Set background color
ax.set_facecolor("#F7F7F7")

# Plot the distributions and set custom colors
sns.distplot(same_disssimilarity, bins=100, kde=True, hist=False, rug=False, label="Same", color=colors[0])
sns.distplot(different_disssimilarity, bins=100, kde=True, hist=False, rug=False, label="Different", color=colors[1])

# Add legend and title
plt.legend(fontsize=14)
plt.title('Density vs Dissimilarity for euclidean distance', fontsize=20)

# Add gridlines
ax.grid(linestyle='--', linewidth=0.5)

# Set axis labels and tick sizes
plt.xlabel("Dissimilarity", fontsize=16)
plt.ylabel("Density", fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Remove top and right spines
sns.despine(top=True, right=True)

plt.show()
# Out:
# C:\Users\AkshatGarg\AppData\Local\Temp\ipykernel_12668\3183135136.py:17: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(same_disssimilarity, bins=100, kde=True, hist=False, rug=False, label="Same", color=colors[0])
# C:\Users\AkshatGarg\AppData\Local\Temp\ipykernel_12668\3183135136.py:18: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(different_disssimilarity, bins=100, kde=True, hist=False, rug=False, label="Different", color=colors[1])
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# checking for mean/average score
from statistics import mean
print("Mean of same images: ",mean(same_disssimilarity))
print("Mean of different images: ",mean(different_disssimilarity))
# Out:
# Mean of same images:  0.3384275741193172
# Mean of different images:  2.723365698867737

# %%
# Prinitng total number of combinations that we tested on
print("Total number of combinations of same images: ", len(same_disssimilarity))
print("Total number of combinations of different images: ", len(different_disssimilarity))
print("Total number of combinations: ", len(same_disssimilarity) + len(different_disssimilarity))
# Out:
# Total number of combinations of same images:  300
# Total number of combinations of different images:  21900
# Total number of combinations:  22200

# %%
# Checking for number of missclassified images
final_list, same_misclassified, different_misclassified = threshold(same_disssimilarity,different_disssimilarity,THRESHOLD_SCORE)

print("Total number of missclassified for threshold score ",THRESHOLD_SCORE," missclassified images: ",len(final_list))
print("Total number of same class missclassified for threshold score ",THRESHOLD_SCORE," missclassified images: ",len(same_misclassified))
print("Total number of different class missclassified for threshold score ",THRESHOLD_SCORE," missclassified images: ",len(different_misclassified))
# Out:
# Total number of missclassified for threshold score  0.3  missclassified images:  201
# Total number of same class missclassified for threshold score  0.3  missclassified images:  142
# Total number of different class missclassified for threshold score  0.3  missclassified images:  59

# %%
import numpy as np
final_list_1 = {}
for i in np.linspace(-0.5,1,250):
    x,_,_ = threshold(same_disssimilarity,different_disssimilarity,i)
    final_list_1[i] = len(x)

plt.plot(final_list_1.keys(),final_list_1.values())

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
